# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../Datasets/dataset_Facebook.csv',sep=';')
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.head(5)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.shape
# Out:
# (500, 19)

# %%
#finds the unique value inside the Type column
data["Type"].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data.isna().sum().sum()
# Out:
# 6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %% [markdown]
# # Data Subsets

# %%
data_photo = data[data['Type']=='Photo']
data_photo.head(5)
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
data_status = data[data['Type']=='Status']
data_status.head(5)
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data_link = data[data['Type']=='Link']
data_link.head(5)
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data_video = data[data['Type']=='Video']
data_video.head(5)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# 183   0.0                      30624                            56950
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # Merge two Subsets

# %%
data_photo_video = pd.concat([data_photo,data_video])
data_photo_video
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
# ...

# %%
data_photo_video.shape
# Out:
# (433, 19)

# %% [markdown]
# # Sorting Data based on most Likes

# %%
data.sort_values(by='like',ascending=False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 111            136736  Photo         1          10             6          8
#
# ...

# %% [markdown]
# # Sorting Data Based on Least Interaction

# %%
least_interaction = data.sort_values(by='Total Interactions')
least_interaction
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 417            104070  Photo         1           3             3         10
# 21             138414  Photo         1          12             7         10
# 441             98195  Photo         1           3             5          4
# 111            136736  Photo         1          10             6          8
# 100            137020  Photo         1          10             4          9
# ..                ...    ...       ...         ...           ...        ...
# 349            117764  Photo         3           5             5         13
# 460             92507  Photo         3           2             1         13
# 168            135428  Photo         1           9             3         10
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
#
# ...

# %% [markdown]
# # Transposing Data

# %%
#Transposing Data meaning chaging the row value with column values and column values with row values

# %%
data_transpose = data.transpose()
data_transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
data_transpose.shape
# Out:
# (19, 500)

# %% [markdown]
# # Shaping and Reshaping Data

# %%
#this is done to add a column to provide a unique value to rach row to further melt and unmelt the data

data['index'] = range(1,len(data)+1)
data.head(5)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # Melting Data to long Format

# %%
#Melting is the process of transforming a dataset from a wide format to a long format.
#In a wide format dataset, each row represents a unique observation, and each column represents a different variable or attribute.

#Unmelting is the process of transforming a dataset from a long format to a wide format.
#In a long format dataset, each row represents a single observation, and there may be multiple rows for each unique observation, each specifying a different variable or attribute.

# %%
data_melt = pd.melt(data,id_vars=['index','Type','Category'],value_name='Value',var_name='Metrics')
data_melt
# Out:
#       index    Type  Category             Metrics     Value
# 0         1   Photo         2    Page total likes  139441.0
# 1         2  Status         2    Page total likes  139441.0
# 2         3   Photo         3    Page total likes  139441.0
# 3         4   Photo         2    Page total likes  139441.0
# 4         5   Photo         2    Page total likes  139441.0
# ...     ...     ...       ...                 ...       ...
# 8495    496   Photo         3  Total Interactions      84.0
# 8496    497   Photo         2  Total Interactions      75.0
# 8497    498   Photo         1  Total Interactions     115.0
# 8498    499   Photo         3  Total Interactions     136.0
# 8499    500   Photo         2  Total Interactions     119.0
#
# [8500 rows x 5 columns]

# %%
#melting the data using melt()

data_melted = pd.melt(data, id_vars='index',  value_vars='Type')
data_melted
# Out:
#      index variable   value
# 0        1     Type   Photo
# 1        2     Type  Status
# 2        3     Type   Photo
# 3        4     Type   Photo
# 4        5     Type   Photo
# ..     ...      ...     ...
# 495    496     Type   Photo
# 496    497     Type   Photo
# 497    498     Type   Photo
# 498    499     Type   Photo
# 499    500     Type   Photo
#
# [500 rows x 3 columns]

# %%
data_melted = pd.melt(data, id_vars='index',  value_vars='Total Interactions')
data_melted
# Out:
#      index            variable  value
# 0        1  Total Interactions    100
# 1        2  Total Interactions    164
# 2        3  Total Interactions     80
# 3        4  Total Interactions   1777
# 4        5  Total Interactions    393
# ..     ...                 ...    ...
# 495    496  Total Interactions     84
# 496    497  Total Interactions     75
# 497    498  Total Interactions    115
# 498    499  Total Interactions    136
# 499    500  Total Interactions    119
#
# [500 rows x 3 columns]

# %% [markdown]
# # Casting the data to wide format

# %%
data_casting = pd.pivot_table(data,index=['Type','Category'],values='like',fill_value=0)
data_casting.head(5)
# Out:
#                       like
# Type  Category
# Link  1          75.650000
#       2          32.000000
#       3          68.000000
# Photo 1         126.000000
#       2         235.857143
