# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../Datasets/Adult/adult.csv')
data
# Out:
#        39          State-gov   77516    Bachelors  13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 1      38            Private  215646      HS-grad   9             Divorced
# 2      53            Private  234721         11th   7   Married-civ-spouse
# 3      28            Private  338409    Bachelors  13   Married-civ-spouse
# 4      37            Private  284582      Masters  14   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32555  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad   9              Widowed
# 32558  22            Private  201490      HS-grad   9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
data.columns = ['Age','Workclass','Wage','Education','Education Number','Marital Status','Occupation','Relationship','Race','Sex','Capital Gain','Capital Loss','Work Hours Per Week','Country','target']

# %%
data
# Out:
#        Age          Workclass    Wage    Education  Education Number  \
# 0       50   Self-emp-not-inc   83311    Bachelors                13
# 1       38            Private  215646      HS-grad                 9
# 2       53            Private  234721         11th                 7
# 3       28            Private  338409    Bachelors                13
# 4       37            Private  284582      Masters                14
# ...    ...                ...     ...          ...               ...
# 32555   27            Private  257302   Assoc-acdm                12
# 32556   40            Private  154374      HS-grad                 9
# 32557   58            Private  151910      HS-grad                 9
# 32558   22            Private  201490      HS-grad                 9
# 32559   52       Self-emp-inc  287927      HS-grad                 9
#
#             Marital Status          Occupation    Relationship    Race  \
# ...

# %%
data.shape
# Out:
# (32560, 15)

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  32560 non-null  int64
#  1   Workclass            32560 non-null  object
#  2   Wage                 32560 non-null  int64
#  3   Education            32560 non-null  object
#  4   Education Number     32560 non-null  int64
#  5   Marital Status       32560 non-null  object
#  6   Occupation           32560 non-null  object
#  7   Relationship         32560 non-null  object
#  8   Race                 32560 non-null  object
#  9   Sex                  32560 non-null  object
#  10  Capital Gain         32560 non-null  int64
#  11  Capital Loss         32560 non-null  int64
#  12  Work Hours Per Week  32560 non-null  int64
#  13  Country              32560 non-null  object
#  14  target               32560 non-null  object
# ...

# %%
data.describe()
# Out:
#                 Age          Wage  Education Number  Capital Gain  \
# count  32560.000000  3.256000e+04      32560.000000  32560.000000
# mean      38.581634  1.897818e+05         10.080590   1077.615172
# std       13.640642  1.055498e+05          2.572709   7385.402999
# min       17.000000  1.228500e+04          1.000000      0.000000
# 25%       28.000000  1.178315e+05          9.000000      0.000000
# 50%       37.000000  1.783630e+05         10.000000      0.000000
# 75%       48.000000  2.370545e+05         12.000000      0.000000
# max       90.000000  1.484705e+06         16.000000  99999.000000
#
#        Capital Loss  Work Hours Per Week
# count  32560.000000         32560.000000
# mean      87.306511            40.437469
# std      402.966116            12.347618
# min        0.000000             1.000000
# 25%        0.000000            40.000000
# 50%        0.000000            40.000000
# 75%        0.000000            45.000000
# ...

# %% [markdown]
# # Subset Based on Country

# %%
data['Country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
data['Country'] = data['Country'].str.strip()

# %%
data['Country'].unique()
# Out:
# array(['United-States', 'Cuba', 'Jamaica', 'India', '?', 'Mexico',
#        'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany',
#        'Iran', 'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia',
#        'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal',
#        'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala',
#        'China', 'Japan', 'Yugoslavia', 'Peru',
#        'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago',
#        'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary',
#        'Holand-Netherlands'], dtype=object)

# %%
data_India = data[data['Country'] == 'India']
data_India
# Out:
#        Age          Workclass    Wage    Education  Education Number  \
# 10      30          State-gov  141297    Bachelors                13
# 891     28            Private  164170    Assoc-voc                11
# 967     48            Private  164966    Bachelors                13
# 1028    48       Self-emp-inc  138370      Masters                14
# 1094    22   Self-emp-not-inc  361280    Bachelors                13
# ...    ...                ...     ...          ...               ...
# 30151   48            Private  119471    Doctorate                16
# 30832   25            Private  110978   Assoc-acdm                12
# 30870   26            Private  160261      Masters                14
# 31326   38          State-gov  125499    Bachelors                13
# 31356   23            Private  143003      Masters                14
#
#                Marital Status        Occupation    Relationship  \
# 10         Married-civ-spouse    Prof-specialty         Husband
# ...

# %%
data_United_State = data[data['Country'] == 'United-States']
data_United_State
# Out:
#        Age          Workclass    Wage    Education  Education Number  \
# 0       50   Self-emp-not-inc   83311    Bachelors                13
# 1       38            Private  215646      HS-grad                 9
# 2       53            Private  234721         11th                 7
# 4       37            Private  284582      Masters                14
# 6       52   Self-emp-not-inc  209642      HS-grad                 9
# ...    ...                ...     ...          ...               ...
# 32555   27            Private  257302   Assoc-acdm                12
# 32556   40            Private  154374      HS-grad                 9
# 32557   58            Private  151910      HS-grad                 9
# 32558   22            Private  201490      HS-grad                 9
# 32559   52       Self-emp-inc  287927      HS-grad                 9
#
#             Marital Status          Occupation    Relationship    Race  \
# ...

# %%
data_Germany = data[data['Country'] == 'Germany']
data_Germany
# Out:
#        Age          Workclass    Wage      Education  Education Number  \
# 121     30            Private   77143      Bachelors                13
# 279     22            Private   34918      Bachelors                13
# 766     22            Private  151790   Some-college                10
# 1008    26            Private  109186   Some-college                10
# 1141    59        Federal-gov  212448        HS-grad                 9
# ...    ...                ...     ...            ...               ...
# 32073   30            Private  318749      Assoc-voc                11
# 32100   45            Private  174794      Bachelors                13
# 32140   34            Private  193344   Some-college                10
# 32235   26            Private  323044   Some-college                10
# 32340   74   Self-emp-not-inc  199136      Bachelors                13
#
#             Marital Status        Occupation    Relationship    Race      Sex  \
# ...

# %%
data_Japan = data[data['Country'] == 'Japan']
data_Japan
# Out:
#        Age          Workclass    Wage      Education  Education Number  \
# 1019    41            Private  198316   Some-college                10
# 1118    53            Private  288020      Bachelors                13
# 1300    29            Private  419721        HS-grad                 9
# 1367    52            Private  152234        HS-grad                 9
# 1755    47   Self-emp-not-inc  162924      Bachelors                13
# ...    ...                ...     ...            ...               ...
# 31756   34            Private  143582   Some-college                10
# 31829   33            Private   72338    Prof-school                15
# 32074   27                  ?  147638        Masters                14
# 32375   40            Private  306225        HS-grad                 9
# 32532   54            Private  337992      Bachelors                13
#
#             Marital Status        Occupation    Relationship  \
# ...

# %% [markdown]
# # Subset based on Sex

# %%
data['Sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
data['Sex'] = data['Sex'].str.strip()
data['Sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data_male = data[data['Sex'] == 'Male']
data_male
# Out:
#        Age          Workclass    Wage      Education  Education Number  \
# 0       50   Self-emp-not-inc   83311      Bachelors                13
# 1       38            Private  215646        HS-grad                 9
# 2       53            Private  234721           11th                 7
# 6       52   Self-emp-not-inc  209642        HS-grad                 9
# 8       42            Private  159449      Bachelors                13
# ...    ...                ...     ...            ...               ...
# 32552   32            Private  116138        Masters                14
# 32553   53            Private  321865        Masters                14
# 32554   22            Private  310152   Some-college                10
# 32556   40            Private  154374        HS-grad                 9
# 32558   22            Private  201490        HS-grad                 9
#
#             Marital Status          Occupation    Relationship  \
# ...

# %%
data_female = data[data['Sex'] == 'Female']
data_female
# Out:
#        Age      Workclass    Wage      Education  Education Number  \
# 3       28        Private  338409      Bachelors                13
# 4       37        Private  284582        Masters                14
# 5       49        Private  160187            9th                 5
# 7       31        Private   45781        Masters                14
# 11      23        Private  122272      Bachelors                13
# ...    ...            ...     ...            ...               ...
# 32545   37        Private  198216     Assoc-acdm                12
# 32548   43      State-gov  255835   Some-college                10
# 32555   27        Private  257302     Assoc-acdm                12
# 32557   58        Private  151910        HS-grad                 9
# 32559   52   Self-emp-inc  287927        HS-grad                 9
#
#                Marital Status        Occupation     Relationship    Race  \
# 3          Married-civ-spouse    Prof-specialty             Wife   Black
# ...

# %% [markdown]
# # Subset based on Race

# %%
data['Race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
data['Race']=data['Race'].str.strip()
data['Race'].unique()
# Out:
# array(['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo',
#        'Other'], dtype=object)

# %%
race_white = data[data['Race']=='White']
race_white
# Out:
#        Age          Workclass    Wage    Education  Education Number  \
# 0       50   Self-emp-not-inc   83311    Bachelors                13
# 1       38            Private  215646      HS-grad                 9
# 4       37            Private  284582      Masters                14
# 6       52   Self-emp-not-inc  209642      HS-grad                 9
# 7       31            Private   45781      Masters                14
# ...    ...                ...     ...          ...               ...
# 32555   27            Private  257302   Assoc-acdm                12
# 32556   40            Private  154374      HS-grad                 9
# 32557   58            Private  151910      HS-grad                 9
# 32558   22            Private  201490      HS-grad                 9
# 32559   52       Self-emp-inc  287927      HS-grad                 9
#
#             Marital Status          Occupation    Relationship   Race     Sex  \
# ...

# %%
race_black = data[data['Race']=='Black']
race_black
# Out:
#        Age Workclass    Wage      Education  Education Number  \
# 2       53   Private  234721           11th                 7
# 3       28   Private  338409      Bachelors                13
# 5       49   Private  160187            9th                 5
# 9       37   Private  280464   Some-college                10
# 12      32   Private  205019     Assoc-acdm                12
# ...    ...       ...     ...            ...               ...
# 32520   33   Private  273243        HS-grad                 9
# 32534   22   Private  325033           12th                 8
# 32536   30   Private  345898        HS-grad                 9
# 32537   38   Private  139180      Bachelors                13
# 32540   41         ?  202822        HS-grad                 9
#
#                Marital Status          Occupation    Relationship   Race  \
# 2          Married-civ-spouse   Handlers-cleaners         Husband  Black
# ...

# %% [markdown]
# # Merge two Subsets

# %%
race_white_black = pd.concat([race_white,race_black])
race_white_black
# Out:
#        Age          Workclass    Wage   Education  Education Number  \
# 0       50   Self-emp-not-inc   83311   Bachelors                13
# 1       38            Private  215646     HS-grad                 9
# 4       37            Private  284582     Masters                14
# 6       52   Self-emp-not-inc  209642     HS-grad                 9
# 7       31            Private   45781     Masters                14
# ...    ...                ...     ...         ...               ...
# 32520   33            Private  273243     HS-grad                 9
# 32534   22            Private  325033        12th                 8
# 32536   30            Private  345898     HS-grad                 9
# 32537   38            Private  139180   Bachelors                13
# 32540   41                  ?  202822     HS-grad                 9
#
#             Marital Status          Occupation    Relationship   Race     Sex  \
# ...

# %%
data.head(5)
# Out:
#    Age          Workclass    Wage   Education  Education Number  \
# 0   50   Self-emp-not-inc   83311   Bachelors                13
# 1   38            Private  215646     HS-grad                 9
# 2   53            Private  234721        11th                 7
# 3   28            Private  338409   Bachelors                13
# 4   37            Private  284582     Masters                14
#
#         Marital Status          Occupation    Relationship   Race     Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband  White    Male
# 1             Divorced   Handlers-cleaners   Not-in-family  White    Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband  Black    Male
# 3   Married-civ-spouse      Prof-specialty            Wife  Black  Female
# 4   Married-civ-spouse     Exec-managerial            Wife  White  Female
#
#    Capital Gain  Capital Loss  Work Hours Per Week        Country  target
# ...

# %% [markdown]
# # Sorting based on Customer Rating

# %%
data = data.rename(columns={'Education Number':'Customer Rating'})

# %%
data_cust_rating = data.sort_values(by='Customer Rating',ascending = False)
data_cust_rating
# Out:
#        Age          Workclass    Wage   Education  Customer Rating  \
# 8279    55          Local-gov   37869   Doctorate               16
# 21839   56            Private  245215   Doctorate               16
# 26267   37   Self-emp-not-inc  137527   Doctorate               16
# 15707   49       Self-emp-inc   94606   Doctorate               16
# 10646   42          Local-gov  185129   Doctorate               16
# ...    ...                ...     ...         ...              ...
# 24174   54            Private  349340   Preschool                1
# 21369   61            Private   98350   Preschool                1
# 8774    20            Private  277700   Preschool                1
# 15058   21            Private  243368   Preschool                1
# 32223   40            Private   70645   Preschool                1
#
#                Marital Status        Occupation    Relationship  \
# 8279            Never-married    Prof-specialty   Not-in-family
# ...

# %% [markdown]
# # Data Transpose

# %%
data_transpose = data.transpose()
data_transpose
# Out:
#                                    0                   1      \
# Age                                   50                  38
# Workclass               Self-emp-not-inc             Private
# Wage                               83311              215646
# Education                      Bachelors             HS-grad
# Customer Rating                       13                   9
# Marital Status        Married-civ-spouse            Divorced
# Occupation               Exec-managerial   Handlers-cleaners
# Relationship                     Husband       Not-in-family
# Race                               White               White
# Sex                                 Male                Male
# Capital Gain                           0                   0
# Capital Loss                           0                   0
# Work Hours Per Week                   13                  40
# Country                    United-States       United-States
# ...

# %% [markdown]
# # Data Melting

# %%
data.head(5)
# Out:
#    Age          Workclass    Wage   Education  Customer Rating  \
# 0   50   Self-emp-not-inc   83311   Bachelors               13
# 1   38            Private  215646     HS-grad                9
# 2   53            Private  234721        11th                7
# 3   28            Private  338409   Bachelors               13
# 4   37            Private  284582     Masters               14
#
#         Marital Status          Occupation    Relationship   Race     Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband  White    Male
# 1             Divorced   Handlers-cleaners   Not-in-family  White    Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband  Black    Male
# 3   Married-civ-spouse      Prof-specialty            Wife  Black  Female
# 4   Married-civ-spouse     Exec-managerial            Wife  White  Female
#
#    Capital Gain  Capital Loss  Work Hours Per Week        Country  target
# ...

# %%
melted_data = pd.melt(data,id_vars=['Sex','Age','Education','Workclass'])
melted_data
# Out:
#            Sex  Age    Education          Workclass variable   value
# 0         Male   50    Bachelors   Self-emp-not-inc     Wage   83311
# 1         Male   38      HS-grad            Private     Wage  215646
# 2         Male   53         11th            Private     Wage  234721
# 3       Female   28    Bachelors            Private     Wage  338409
# 4       Female   37      Masters            Private     Wage  284582
# ...        ...  ...          ...                ...      ...     ...
# 358155  Female   27   Assoc-acdm            Private   target   <=50K
# 358156    Male   40      HS-grad            Private   target    >50K
# 358157  Female   58      HS-grad            Private   target   <=50K
# 358158    Male   22      HS-grad            Private   target   <=50K
# 358159  Female   52      HS-grad       Self-emp-inc   target    >50K
#
# [358160 rows x 6 columns]

# %% [markdown]
# # Casting Data

# %%
casted_data = pd.pivot_table(data,index=['Workclass','Occupation'],values=['Work Hours Per Week'])
casted_data[1:]
# Out:
#                                Work Hours Per Week
# Workclass   Occupation
# Federal-gov Adm-clerical                 40.154574
#             Armed-Forces                 40.666667
#             Craft-repair                 40.781250
#             Exec-managerial              42.572222
#             Farming-fishing              40.000000
# ...                                            ...
# Without-pay Farming-fishing              36.666667
#             Handlers-cleaners            40.000000
#             Machine-op-inspct            25.000000
#             Other-service                55.000000
#             Transport-moving             20.000000
#
# [82 rows x 1 columns]
